# %%
import json
from pathlib import Path, PurePath

DATA_DIR = "data"
PATTERN = "**/*.dat"
OUTPUT_FILE = "data.json"

path = Path(DATA_DIR)

json_data = {}

for i, f in enumerate(path.glob(PATTERN)):
  #if i > 1: break  # for testing
  p = Path(f)
  parent = p.relative_to(DATA_DIR).parent
  print(p, p.name, p.relative_to(DATA_DIR).parent)
  item = {}
  path = str(p).replace("\\", "/")
  value = p.read_text()
  json_data[path] = value
  
  
json_options = {'sort_keys':True, 'indent':2, 'separators':(',', ': ')}

json_str = json.dumps(json_data, **json_options)
print(json_str[:1000] + " ...")

with open(OUTPUT_FILE, "w") as out:
  json.dump(json_data, out, **json_options)
# Out:
# data\2.dat 2.dat .
# data\bird.dat bird.dat .
# data\custom.dat custom.dat .
# data\debug.dat debug.dat .
# data\debug2.dat debug2.dat .
# data\diamond.dat diamond.dat .
# data\dude.dat dude.dat .
# data\dude_holes.dat dude_holes.dat .
# data\France.dat France.dat .
# data\funny.dat funny.dat .
# data\glu_example.dat glu_example.dat .
# data\glu_winding.dat glu_winding.dat .
# data\issue39.dat issue39.dat .
# data\issue39_holes.dat issue39_holes.dat .
# data\issue39_steiner.dat issue39_steiner.dat .
# data\issue49.dat issue49.dat .
# data\issue53.dat issue53.dat .
# data\issue53_hole.dat issue53_hole.dat .
# data\issue58.dat issue58.dat .
# data\kzer-za.dat kzer-za.dat .
# data\map_fixed.dat map_fixed.dat .
# data\map_invalid.dat map_invalid.dat .
# data\nazca_heron.dat nazca_heron.dat .
# data\nazca_monkey.dat nazca_monkey.dat .
# data\sketchup.dat sketchup.dat .
# data\spiral.dat spiral.dat .
# data\star.dat star.dat .
# data\strange.dat strange.dat .
# data\tank.dat tank.dat .
# data\test.dat test.dat .
# data\issue34\assertion.dat assertion.dat issue34
# data\issue34\dump.dat dump.dat issue34
# data\issue34\dump1208.dat dump1208.dat issue34
# data\issue34\dump157.dat dump157.dat issue34
# data\issue34\dump438.dat dump438.dat issue34
# data\issue34\dump495.dat dump495.dat issue34
# data\issue34\dump542.dat dump542.dat issue34
# data\issue34\dump591.dat dump591.dat issue34
# data\issue34\dump594.dat dump594.dat issue34
# data\issue34\dump621.dat dump621.dat issue34
# data\issue34\dump627.dat dump627.dat issue34
# data\issue34\dump640.dat dump640.dat issue34
# data\issue34\dump675.dat dump675.dat issue34
# data\issue34\dump690.dat dump690.dat issue34
# data\issue34\dump720.dat dump720.dat issue34
# data\issue34\dump737.dat dump737.dat issue34
# data\issue34\dump805.dat dump805.dat issue34
# data\issue34\dump857.dat dump857.dat issue34
# data\issue34\dump862.dat dump862.dat issue34
# data\issue34\dump910.dat dump910.dat issue34
# data\issue34\dump_.dat dump_.dat issue34
# data\issue34\overflow2.dat overflow2.dat issue34
# data\issue34\stackoverflow.dat stackoverflow.dat issue34
# data\issue34\stackoverflow_uncommented.dat stackoverflow_uncommented.dat issue34
# {
#   "data/2.dat": "2158.9981 2350.2286\n2158.9981 3245.4557\n-1042.9463 3245.4557\n-1042.9463 2496.1895\n91.149593 800.20639\n441.75649 251.73749\n648.06929 -97.04991\n765.46219 -332.30851\n849.31479 -540.20071\n899.62689 -720.72671\n916.39869 -873.88651\n896.13819 -1060.7944\n835.35969 -1193.3788\n789.54889 -1239.4959\n733.15879 -1272.4376\n666.18939 -1292.204\n588.64059 -1298.7951\n511.08979 -1291.4964\n444.11959 -1269.6012\n387.73029 -1233.1107\n341.92169 -1182.0263\n306.46619 -1109.2461\n281.14119 -1007.6808\n260.88259 -718.19491\n260.88259 -218.68401\n-1042.9463 -218.68401\n-1042.9463 -410.05511\n-1030.3404 -804.55201\n-992.52205 -1105.8022\n-958.08057 -1232.6032\n-905.18018 -1358.3923\n-833.82067 -1483.1695\n-744.00213 -1606.9348\n-637.5262 -1722.6871\n-516.1928 -1823.4397\n-380.00205 -1909.1927\n-228.95374 -1979.9461\n-62.599167 -2035.2866\n119.51329 -2074.8167\n317.38399 -2098.5364\n531.01279 -2106.4456\n938.57049 -2082.2155\n1122.512 -2051.9328\n1293.2285 -2009.5383\n1450.7202 ...
